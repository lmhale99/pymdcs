# %% [markdown]
# # pymdcs Demonstration
#
# This Notebook provides basic documentation and demonstration for using the pymcds module for accessing 1.X versions of the MDCS database.

# %% [markdown]
# ## Python library imports

# %%
# Python standard library imports
from __future__ import print_function
import os

# pymdcs package import
import mdcs

# %% [markdown]
# ## 1. Database access
#
#
# **MDCS.\_\_init\_\_()**
#
# The operations of the package are built around the MDCS class.  An MDCS object is initialized by specifying the database access information.
#
# Parameters
#
# - __host__ (*str*) The url where the MDCS database is hosted.
#
# - __user__ (*str, optional*) Your username for the database.  If not given, a prompt will ask for it.
#
# - __pswd__ (*str, optional*) The password associated with the username and database.  If not given, a prompt will ask for it.
#
# - __cert__ (*str, optional*) The file path to a certificate file, if needed, to access the database.

# %%
curator = mdcs.MDCS('https://potentials.nist.gov')
print(curator)
# Out:
# username: lmh1
# password:········
# MDCS @ https://potentials.nist.gov (lmh1)

# %% [markdown]
# **MDCS.database_remember()**
#
# If you wish, the access information can be saved for easier access later with the database_remember() method.
#
# Parameters
#
# - __name__ (*str*) A name to assign to the database to access it later.
#
# - __include_pswd__ (*bool, optional*) Flag indicating if the password is to be saved as well.  Default value is False.
#
# __NOTE__: This information is stored locally as text in file .mdcs located in the same directory as the mdcs.py script.  Do not save password information if others may have access to the .mdcs file!

# %%
curator.database_remember('potentials', include_pswd=True)

# %% [markdown]
# __database_load()__
#
# Loads saved database system information based on the database's assigned name.  If password is not saved, a prompt will ask for it.
#
# Parameters
#
# - __name__ (*str*) The name assigned to the database to access.
#
# Returns
#
# - (*mdcs.MDCS*) An MDCS object with the loaded database access information.

# %%
curator = mdcs.database_load('potentials')
print(curator)
# Out:
# MDCS @ https://potentials.nist.gov (lmh1)

# %% [markdown]
# __database_list()__
#
# Lists names of all stored access informations.
#
# Returns
#
# - (*list*) The names assigned to all access information.

# %%
mdcs.database_list()
# Out:
# ['iprhub', 'potentials']

# %% [markdown]
# __database_info()__
#
# Shows info for stored access information.  If pswd is stored, will replace value with True.
#
# Parameters
#
# - __name__ (*str*) The name assigned to the database to get values for.
#
# Returns
#
# - (*dict*) Contains the keys 'host', 'user', 'cert', and 'pswd'.

# %%
mdcs.database_info('potentials')
# Out:
# {'host': 'https://potentials.nist.gov',
#  'user': 'lmh1',
#  'cert': None,
#  'pswd': True}

# %% [markdown]
# __database_forget()__
#
# Deletes stored access information.
#
# Parameters
#
# - __name__ (*str*) The name assigned to stored access information.

# %%
#mdcs.database_forget('potentials')

# %% [markdown]
# ## 2. Exploring

# %% [markdown]
# __MDCS.template_select_all()__
#
# Gets a list of all templates in the MDCS instance.
#
# Returns
#
# - (*pandas.DataFrame*) All templates.

# %%
curator.template_select_all()
# Out:
#                  title                                  filename  \
# 0            Potential          record-interatomic-potential.xsd
# 1              Request  record-interatomic-potential-request.xsd
# 2               Family   record-interatomic-potential-family.xsd
# 3                  FAQ      record-interatomic-potential-faq.xsd
# 4               Action   record-interatomic-potential-action.xsd
# 5  PotentialProperties       record-per-potential-properties.xsd
#
#                                              content  \
# 0  <?xml version="1.0" encoding="UTF-8" standalon...
# 1  <?xml version="1.0" encoding="UTF-8" standalon...
# 2  <?xml version="1.0" encoding="UTF-8" standalon...
# 3  <?xml version="1.0" encoding="UTF-8" standalon...
# 4  <?xml version="1.0" encoding="UTF-8" standalon...
# 5  <?xml version="1.0" encoding="UTF-8" standalon...
#
#             templateVersion  version  \
# 0  5ab3ec793de622009710ff1b        1
# 1  5ab3edc73de622009710ff1e        1
# 2  5b44c3a086e02c00a689ff57        1
# 3  5b44c3c886e02c00a689ff59        1
# 4  5b44c3e186e02c00a689ff5b        1
# 5  5b4f8f9286e02c00a68121f6        1
#
#                                        hash dependencies  \
# 0  4b7dde5826186a44ef00d396265a02ef90d75382           []
# 1  27d88e30f7af31b570967e3e37bf1fe4e7d1e29a           []
# 2  4bc28ba6f5a25afedd83582e089fe76dd1e73a53           []
# 3  12ba7d0270c5fa8d169ff54a5ef24e558e94b0d4           []
# 4  53b2f757bb148da3c461b65f1a61ff1080f3651c           []
# 5  1c54ec4f8ecd0b6600ae00846a6c1eb52d1b67ed           []
#
#                                            exporters XSLTFiles  \
# 0  [{'id': '5a83430d7d600ded62fe262d', 'name': 'X...        []
# 1  [{'id': '5a83430d7d600ded62fe262d', 'name': 'X...        []
# 2  [{'id': '5a83430d7d600ded62fe262d', 'name': 'X...        []
# 3  [{'id': '5a83430d7d600ded62fe262d', 'name': 'X...        []
# 4  [{'id': '5a83430d7d600ded62fe262d', 'name': 'X...        []
# 5  [{'id': '5a83430d7d600ded62fe262d', 'name': 'X...        []
#
#                          id
# 0  5ab3ec793de622009710ff1c
# 1  5ab3edc73de622009710ff1f
# 2  5b44c3a086e02c00a689ff58
# 3  5b44c3c886e02c00a689ff5a
# 4  5b44c3e186e02c00a689ff5c
# 5  5b4f8f9286e02c00a68121f7

# %% [markdown]
# __MDCS.template_select()__
#
# Gets a list of all templates matching the given parameters.  One positional parameter is allowed, which will be tested against title, id, and filename if they are not given separately.
#
# Parameters
#
# - __title__ (*str*) The title assigned to the template.
# - __id__ (*str*) The template's unique id.
# - __filename__ (*str*) The filename for the template.
# - __version__ (*int*) Version number for the template.
# - __templateVersion__ (*str*) Unique id for template and version.
# - __hash__ (*str*) Database hash.
#
# Returns
#
# - (*pandas.DataFrame*) All matching templates.

# %%
curator.template_select(title='Potential')
# Out:
#        title                          filename  \
# 0  Potential  record-interatomic-potential.xsd
#
#                                              content  \
# 0  <?xml version="1.0" encoding="UTF-8" standalon...
#
#             templateVersion  version  \
# 0  5ab3ec793de622009710ff1b        1
#
#                                        hash dependencies  \
# 0  4b7dde5826186a44ef00d396265a02ef90d75382           []
#
#                                            exporters XSLTFiles  \
# 0  [{'id': '5a83430d7d600ded62fe262d', 'name': 'X...        []
#
#                          id
# 0  5ab3ec793de622009710ff1c

# %% [markdown]
# __MDCS.template_select_one()__
#
# Get a single templates matching the given parameters.  One positional parameter is allowed, which will be tested against title, id, and filename if they are not given separately.  Will issue an error if no or multiple matching templates are found.
#
# Parameters
#
# - __title__ (*str*) The title assigned to the template.
#
# - __id__ (*str*) The template's unique id.
#
# - __filename__ (*str*) The filename for the template.
#
# - __version__ (*int*) Version number for the template.
#
# - __templateVersion__ (*str*) Unique id for template and version.
#
# - __hash__ (*str*) Database hash.
#
# Returns
#
# - (*pandas.Series*) The matching template.
#
# Raises
#
# - (*ValueError*) If no or multiple matching templates are found.

# %%
curator.template_select_one(title='Potential')
# Out:
# title                                                      Potential
# filename                            record-interatomic-potential.xsd
# content            <?xml version="1.0" encoding="UTF-8" standalon...
# templateVersion                             5ab3ec793de622009710ff1b
# version                                                            1
# hash                        4b7dde5826186a44ef00d396265a02ef90d75382
# dependencies                                                      []
# exporters          [{'id': '5a83430d7d600ded62fe262d', 'name': 'X...
# XSLTFiles                                                         []
# id                                          5ab3ec793de622009710ff1c
# Name: 0, dtype: object

# %% [markdown]
# __MDCS.select_all()__
#
# Get all data from the MDCS server.
#
# Parameters
#
# - __format__ (*str, optional*) Format to return record content as, can be either 'xml', or 'json'.
#
# Returns
#
# - (*pandas.DataFrame*) All stored records.

# %%
curator.select_all()
# Out:
#                                                  title  \
# 0                      New postings for Cu, Fe, and Ni
# 1                                New posting for Au-Pt
# 2    Updated postings for Ag, Al, Au, Co, Ag-Au-Cu,...
# 3                             Updated posting for U-Zr
# 4                                 New posting for Si-U
# 5                              New posting for Fe-Cr-W
# 6                                 New posting for Fe-W
# 7                                 New posting for Be-O
# 8    Updated reference and potential file for the M...
# 9                                   New posting for Tb
# 10                             New posting for Ni-Ti-V
# 11                                New posting for U-Mo
# 12                               New posting for Au-Si
# 13                               New posting for Fe-Cr
# 14                                New posting for W-Re
# 15                                  New posting for Cu
# 16                       Updated postings for Zr and V
# 17         Updated postings for Ag, Au, Cu, Ni, and Ti
# 18          Updated postings for Cs, K, Li, Na, and Rb
# 19                             Updated posting for Mo
# 20                               New posting for Cu-Zr
# 21                                  New posting for Au
# 22                            Updated posting for TWIP
# 23                              Updated posting for Fe
# 24                                New posting for Li-S
# 25                     New postings for Cu, Fe, and Ni
# 26                          New postings for Au and Al
# 27                               New posting for Fe-Mn
# 28                                   New posting for W
# 29                                  New posting for Fe
# ..                                                 ...
# 512           potential.2016--Nichol-A-Ackland-G-J--Na
# 513           potential.2016--Nichol-A-Ackland-G-J--Rb
# 514    potential.2016--Tseplyaev-V-I-Starikov-S-V--U-N
# 515        potential.2016--Wilson-S-R-Mendelev-M-I--Mg
# 516          potential.2016--Zhang-P-Trinkle-D-R--Ti-O
# 517  potential.2016--Zhang-Y-Ashcraft-R-Mendelev-M-...
# 518  potential.2017--Beeler-B-Baskes-M-Andersson-D-...
# 519  potential.2017--Bonny-G-Bakaev-A-Terentyev-D-M...
# 520  potential.2017--Maisel-S-B-Ko-W-S-Zhang-J-L-et...
# 521  potential.2017--OBrien-C-J-Barr-C-M-Price-P-M-...
# 522                  potential.2017--Purja-Pun-G-P--Au
# 523   potential.2017--Smirnova-D-E-Starikov-S-V--Zr-Nb
# 524      potential.2017--Wang-P-Xu-S-Liu-J-et-al--TWIP
# 525  potential.2018--Byggmastar-J-Hodille-E-A-Ferro...
# 526            potential.2018--Etesami-S-A-Asadi-E--Cu
# 527            potential.2018--Etesami-S-A-Asadi-E--Fe
# 528            potential.2018--Etesami-S-A-Asadi-E--Ni
# 529                   potential.2018--Mendelev-M-I--Tb
# 530  potential.2018--Starikov-S-V-Kolotova-L-N-Kuks...
# 531  potential.2018--Starikov-S-V-Lopanitsyna-N-Y-S...
# 532  potential.2013--Agrawal-A-Mishra-R-Ward-L-et-a...
# 533  Updated Liu potentials with LAMMPS-compatible ...
# 534  Updated Cu potential with publication information
# 535  potential.2012--Norman-G-E-Starikov-S-V-Stegai...
# 536                                 New posting for Au
# 537  potential.2018--Dickel-D-E-Baskes-M-I-Aslam-I-...
# 538                potential.2018--Mendelev-M-I--Ag-Ni
# 539                              New posting for Ag-Ni
# 540                           New posting for Al-Mg-Zn
# 541                             Major website overhaul
#
#                        schema  \
# 0    5b44c3e186e02c00a689ff5c
# 1    5b44c3e186e02c00a689ff5c
# 2    5b44c3e186e02c00a689ff5c
# 3    5b44c3e186e02c00a689ff5c
# 4    5b44c3e186e02c00a689ff5c
# 5    5b44c3e186e02c00a689ff5c
# 6    5b44c3e186e02c00a689ff5c
# 7    5b44c3e186e02c00a689ff5c
# 8    5b44c3e186e02c00a689ff5c
# 9    5b44c3e186e02c00a689ff5c
# 10   5b44c3e186e02c00a689ff5c
# 11   5b44c3e186e02c00a689ff5c
# 12   5b44c3e186e02c00a689ff5c
# 13   5b44c3e186e02c00a689ff5c
# 14   5b44c3e186e02c00a689ff5c
# 15   5b44c3e186e02c00a689ff5c
# 16   5b44c3e186e02c00a689ff5c
# 17   5b44c3e186e02c00a689ff5c
# 18   5b44c3e186e02c00a689ff5c
# 19   5b44c3e186e02c00a689ff5c
# 20   5b44c3e186e02c00a689ff5c
# 21   5b44c3e186e02c00a689ff5c
# 22   5b44c3e186e02c00a689ff5c
# 23   5b44c3e186e02c00a689ff5c
# 24   5b44c3e186e02c00a689ff5c
# 25   5b44c3e186e02c00a689ff5c
# 26   5b44c3e186e02c00a689ff5c
# 27   5b44c3e186e02c00a689ff5c
# 28   5b44c3e186e02c00a689ff5c
# 29   5b44c3e186e02c00a689ff5c
# ..                        ...
# 512  5ab3ec793de622009710ff1c
# 513  5ab3ec793de622009710ff1c
# 514  5ab3ec793de622009710ff1c
# 515  5ab3ec793de622009710ff1c
# 516  5ab3ec793de622009710ff1c
# 517  5ab3ec793de622009710ff1c
# 518  5ab3ec793de622009710ff1c
# 519  5ab3ec793de622009710ff1c
# 520  5ab3ec793de622009710ff1c
# 521  5ab3ec793de622009710ff1c
# 522  5ab3ec793de622009710ff1c
# 523  5ab3ec793de622009710ff1c
# 524  5ab3ec793de622009710ff1c
# 525  5ab3ec793de622009710ff1c
# 526  5ab3ec793de622009710ff1c
# 527  5ab3ec793de622009710ff1c
# 528  5ab3ec793de622009710ff1c
# 529  5ab3ec793de622009710ff1c
# 530  5ab3ec793de622009710ff1c
# 531  5ab3ec793de622009710ff1c
# 532  5ab3ec793de622009710ff1c
# 533  5b44c3e186e02c00a689ff5c
# 534  5b44c3e186e02c00a689ff5c
# 535  5ab3ec793de622009710ff1c
# 536  5b44c3e186e02c00a689ff5c
# 537  5ab3ec793de622009710ff1c
# 538  5ab3ec793de622009710ff1c
# 539  5b44c3e186e02c00a689ff5c
# 540  5b44c3e186e02c00a689ff5c
# 541  5b44c3e186e02c00a689ff5c
#
#                                                content  \
# 0    <action  xmlns:xsi="http://www.w3.org/2001/XML...
# 1    <action  xmlns:xsi="http://www.w3.org/2001/XML...
# 2    <action  xmlns:xsi="http://www.w3.org/2001/XML...
# 3    <action  xmlns:xsi="http://www.w3.org/2001/XML...
# 4    <action  xmlns:xsi="http://www.w3.org/2001/XML...
# 5    <action  xmlns:xsi="http://www.w3.org/2001/XML...
# 6    <action  xmlns:xsi="http://www.w3.org/2001/XML...
# 7    <action  xmlns:xsi="http://www.w3.org/2001/XML...
# 8    <action  xmlns:xsi="http://www.w3.org/2001/XML...
# 9    <action  xmlns:xsi="http://www.w3.org/2001/XML...
# 10   <action  xmlns:xsi="http://www.w3.org/2001/XML...
# 11   <action  xmlns:xsi="http://www.w3.org/2001/XML...
# 12   <action  xmlns:xsi="http://www.w3.org/2001/XML...
# 13   <action  xmlns:xsi="http://www.w3.org/2001/XML...
# 14   <action  xmlns:xsi="http://www.w3.org/2001/XML...
# 15   <action  xmlns:xsi="http://www.w3.org/2001/XML...
# 16   <action  xmlns:xsi="http://www.w3.org/2001/XML...
# 17   <action  xmlns:xsi="http://www.w3.org/2001/XML...
# 18   <action  xmlns:xsi="http://www.w3.org/2001/XML...
# 19   <action  xmlns:xsi="http://www.w3.org/2001/XML...
# 20   <action  xmlns:xsi="http://www.w3.org/2001/XML...
# 21   <action  xmlns:xsi="http://www.w3.org/2001/XML...
# 22   <action  xmlns:xsi="http://www.w3.org/2001/XML...
# 23   <action  xmlns:xsi="http://www.w3.org/2001/XML...
# 24   <action  xmlns:xsi="http://www.w3.org/2001/XML...
# 25   <action  xmlns:xsi="http://www.w3.org/2001/XML...
# 26   <action  xmlns:xsi="http://www.w3.org/2001/XML...
# 27   <action  xmlns:xsi="http://www.w3.org/2001/XML...
# 28   <action  xmlns:xsi="http://www.w3.org/2001/XML...
# 29   <action  xmlns:xsi="http://www.w3.org/2001/XML...
# ..                                                 ...
# 512  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 513  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 514  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 515  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 516  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 517  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 518  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 519  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 520  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 521  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 522  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 523  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 524  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 525  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 526  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 527  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 528  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 529  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 530  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 531  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 532  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 533  <action  xmlns:xsi="http://www.w3.org/2001/XML...
# 534  <action  xmlns:xsi="http://www.w3.org/2001/XML...
# 535  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 536  <action  xmlns:xsi="http://www.w3.org/2001/XML...
# 537  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 538  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 539  <action  xmlns:xsi="http://www.w3.org/2001/XML...
# 540  <action  xmlns:xsi="http://www.w3.org/2001/XML...
# 541  <action  xmlns:xsi="http://www.w3.org/2001/XML...
#
#                           _id schema_title
# 0    5b44f24a86e02c00a68a082a         None
# 1    5b44f26686e02c00a68a0946         None
# 2    5b44fc5386e02c00a68a1591         None
# 3    5b44fd1c86e02c00a68a16b9         None
# 4    5b44fd8c86e02c00a68a17df         None
# 5    5b44fddd86e02c00a68a197d         None
# 6    5b44fe4086e02c00a68a1aa1         None
# 7    5b44fe8c86e02c00a68a1bc5         None
# 8    5b44fee486e02c00a68a1c6f         None
# 9    5b44ff2286e02c00a68a1d1a         None
# 10   5b44ff6686e02c00a68a1ec4         None
# 11   5b44ffa886e02c00a68a1fe8         None
# 12   5b45003486e02c00a68a210c         None
# 13   5b4500c186e02c00a68a2231         None
# 14   5b4501ba86e02c00a68a2355         None
# 15   5b45024886e02c00a68a23ff         None
# 16   5b45029f86e02c00a68a253b         None
# 17   5b45032586e02c00a68a282d         None
# 18   5b4503ae86e02c00a68a2b1f         None
# 19   5b45045b86e02c00a68a2bcd         None
# 20   5b4504c286e02c00a68a2cf2         None
# 21   5b45054386e02c00a68a2d9c         None
# 22   5b45059186e02c00a68a2ec5         None
# 23   5b4506ab86e02c00a68a3548         None
# 24   5b4506ee86e02c00a68a366c         None
# 25   5b45074186e02c00a68a383a         None
# 26   5b45078b86e02c00a68a3976         None
# 27   5b4507e386e02c00a68a3ab2         None
# 28   5b45081586e02c00a68a3b5c         None
# 29   5b45085086e02c00a68a3c06         None
# ..                        ...          ...
# 512  5b50fc7486e02c00a6812ab4         None
# 513  5b50fc7686e02c00a6812ab7         None
# 514  5b50fc7786e02c00a6812aba         None
# 515  5b50fc7886e02c00a6812abd         None
# 516  5b50fc7a86e02c00a6812ac0         None
# 517  5b50fc7b86e02c00a6812ac3         None
# 518  5b50fc7c86e02c00a6812ac6         None
# 519  5b50fc7e86e02c00a6812ac9         None
# 520  5b50fc7f86e02c00a6812acc         None
# 521  5b50fc8186e02c00a6812acf         None
# 522  5b50fc8286e02c00a6812ad2         None
# 523  5b50fc8386e02c00a6812ad5         None
# 524  5b50fc8586e02c00a6812ad8         None
# 525  5b50fc8686e02c00a6812adb         None
# 526  5b50fc8786e02c00a6812ade         None
# 527  5b50fc8986e02c00a6812ae1         None
# 528  5b50fc8a86e02c00a6812ae4         None
# 529  5b50fc8b86e02c00a6812ae7         None
# 530  5b50fc8d86e02c00a6812aea         None
# 531  5b50fc8e86e02c00a6812aed         None
# 532  5b50fc8f86e02c00a6812af0         None
# 533  5b5b4e46512605009158dbf3         None
# 534  5b5b4ecb512605009158dc23         None
# 535  5b5b5acb512605009158dc28         None
# 536  5b5b5c40512605009158dc59         None
# 537  5b5b64a3512605009158dc5d         None
# 538  5b5b6741512605009158dc61         None
# 539  5b5b6c84512605009158dc92         None
# 540  5b5b6cc6512605009158dcc2         None
# 541  5b5b6d1c512605009158dcdd         None
#
# [542 rows x 5 columns]

# %% [markdown]
# __MDCS.select()__
#
# Gets a list of all records matching the given parameters.  One positional parameter is allowed, which will be tested against title, and id, if they are not given separately.
#
# Parameters
#
# - __title__ (*str, optional*) The title assigned to the record.
#
# - __id__ (*str, optional*) The records's unique id.
#
# - __template__ (*pandas.Series, str or dict, optional*) The template associated with the record.  If str, will be searched against the template's id, title, and filename.  If dict, allows multiple template parameters to be specified in matching correct template.
#
# - __format__ (*str, optional*) Format to return record content as, can be either 'xml', or 'json'.
#
# Returns
#
# - (*pandas.DataFrame*) All matching records.

# %%
curator.select(template='Potential')
# Out:
#                                                  title  \
# 0                    potential.1985--Foiles-S-M--Ni-Cu
# 1           potential.1987--Ackland-G-J-Thetford-R--Mo
# 2           potential.1987--Ackland-G-J-Thetford-R--Nb
# 3           potential.1987--Ackland-G-J-Thetford-R--Ta
# 4            potential.1987--Ackland-G-J-Thetford-R--V
# 5            potential.1987--Ackland-G-J-Thetford-R--W
# 6    potential.1987--Ackland-G-J-Tichy-G-Vitek-V-Fi...
# 7    potential.1987--Ackland-G-J-Tichy-G-Vitek-V-Fi...
# 8    potential.1987--Ackland-G-J-Tichy-G-Vitek-V-Fi...
# 9    potential.1987--Ackland-G-J-Tichy-G-Vitek-V-Fi...
# 10   potential.1989--Adams-J-B-Foiles-S-M-Wolfer-W-...
# 11   potential.1989--Adams-J-B-Foiles-S-M-Wolfer-W-...
# 12   potential.1989--Adams-J-B-Foiles-S-M-Wolfer-W-...
# 13   potential.1989--Adams-J-B-Foiles-S-M-Wolfer-W-...
# 14   potential.1989--Adams-J-B-Foiles-S-M-Wolfer-W-...
# 15   potential.1989--Adams-J-B-Foiles-S-M-Wolfer-W-...
# 16                     potential.1990--Ackland-G-J--Pt
# 17             potential.1990--Ackland-G-J-Vitek-V--Cu
# 18                     potential.1992--Ackland-G-J--Ti
# 19                      potential.1992--Baskes-M-I--Si
# 20   potential.1995--Ackland-G-J-Wooding-S-J-Bacon-...
# 21   potential.1995--Angelo-J-E-Moody-N-R-Baskes-M-...
# 22          potential.1996--Farkas-D-Jones-C--Nb-Ti-Al
# 23   potential.1997--Ackland-G-J-Bacon-D-J-Calder-A...
# 24   potential.1997--Liu-X-Y-Ohotnicky-P-P-Adams-J-...
# 25            potential.1998--Liu-X-Y-Adams-J-B--Al-Mg
# 26   potential.1999--Liu-X-Y-Liu-C-L-Borucki-L-J--A...
# 27   potential.1999--Mishin-Y-Farkas-D-Mehl-M-J-Pap...
# 28   potential.1999--Mishin-Y-Farkas-D-Mehl-M-J-Pap...
# 29   potential.2000--Landa-A-Wynblatt-P-Siegel-D-J-...
# ..                                                 ...
# 160  potential.2016--Mendelev-M-I-Underwood-T-L-Ack...
# 161  potential.2016--Mendelev-M-I-Underwood-T-L-Ack...
# 162  potential.2016--Mendelev-M-I-Underwood-T-L-Ack...
# 163           potential.2016--Nichol-A-Ackland-G-J--Cs
# 164            potential.2016--Nichol-A-Ackland-G-J--K
# 165           potential.2016--Nichol-A-Ackland-G-J--Li
# 166           potential.2016--Nichol-A-Ackland-G-J--Na
# 167           potential.2016--Nichol-A-Ackland-G-J--Rb
# 168    potential.2016--Tseplyaev-V-I-Starikov-S-V--U-N
# 169        potential.2016--Wilson-S-R-Mendelev-M-I--Mg
# 170          potential.2016--Zhang-P-Trinkle-D-R--Ti-O
# 171  potential.2016--Zhang-Y-Ashcraft-R-Mendelev-M-...
# 172  potential.2017--Beeler-B-Baskes-M-Andersson-D-...
# 173  potential.2017--Bonny-G-Bakaev-A-Terentyev-D-M...
# 174  potential.2017--Maisel-S-B-Ko-W-S-Zhang-J-L-et...
# 175  potential.2017--OBrien-C-J-Barr-C-M-Price-P-M-...
# 176                  potential.2017--Purja-Pun-G-P--Au
# 177   potential.2017--Smirnova-D-E-Starikov-S-V--Zr-Nb
# 178      potential.2017--Wang-P-Xu-S-Liu-J-et-al--TWIP
# 179  potential.2018--Byggmastar-J-Hodille-E-A-Ferro...
# 180            potential.2018--Etesami-S-A-Asadi-E--Cu
# 181            potential.2018--Etesami-S-A-Asadi-E--Fe
# 182            potential.2018--Etesami-S-A-Asadi-E--Ni
# 183                   potential.2018--Mendelev-M-I--Tb
# 184  potential.2018--Starikov-S-V-Kolotova-L-N-Kuks...
# 185  potential.2018--Starikov-S-V-Lopanitsyna-N-Y-S...
# 186  potential.2013--Agrawal-A-Mishra-R-Ward-L-et-a...
# 187  potential.2012--Norman-G-E-Starikov-S-V-Stegai...
# 188  potential.2018--Dickel-D-E-Baskes-M-I-Aslam-I-...
# 189                potential.2018--Mendelev-M-I--Ag-Ni
#
#                        schema  \
# 0    5ab3ec793de622009710ff1c
# 1    5ab3ec793de622009710ff1c
# 2    5ab3ec793de622009710ff1c
# 3    5ab3ec793de622009710ff1c
# 4    5ab3ec793de622009710ff1c
# 5    5ab3ec793de622009710ff1c
# 6    5ab3ec793de622009710ff1c
# 7    5ab3ec793de622009710ff1c
# 8    5ab3ec793de622009710ff1c
# 9    5ab3ec793de622009710ff1c
# 10   5ab3ec793de622009710ff1c
# 11   5ab3ec793de622009710ff1c
# 12   5ab3ec793de622009710ff1c
# 13   5ab3ec793de622009710ff1c
# 14   5ab3ec793de622009710ff1c
# 15   5ab3ec793de622009710ff1c
# 16   5ab3ec793de622009710ff1c
# 17   5ab3ec793de622009710ff1c
# 18   5ab3ec793de622009710ff1c
# 19   5ab3ec793de622009710ff1c
# 20   5ab3ec793de622009710ff1c
# 21   5ab3ec793de622009710ff1c
# 22   5ab3ec793de622009710ff1c
# 23   5ab3ec793de622009710ff1c
# 24   5ab3ec793de622009710ff1c
# 25   5ab3ec793de622009710ff1c
# 26   5ab3ec793de622009710ff1c
# 27   5ab3ec793de622009710ff1c
# 28   5ab3ec793de622009710ff1c
# 29   5ab3ec793de622009710ff1c
# ..                        ...
# 160  5ab3ec793de622009710ff1c
# 161  5ab3ec793de622009710ff1c
# 162  5ab3ec793de622009710ff1c
# 163  5ab3ec793de622009710ff1c
# 164  5ab3ec793de622009710ff1c
# 165  5ab3ec793de622009710ff1c
# 166  5ab3ec793de622009710ff1c
# 167  5ab3ec793de622009710ff1c
# 168  5ab3ec793de622009710ff1c
# 169  5ab3ec793de622009710ff1c
# 170  5ab3ec793de622009710ff1c
# 171  5ab3ec793de622009710ff1c
# 172  5ab3ec793de622009710ff1c
# 173  5ab3ec793de622009710ff1c
# 174  5ab3ec793de622009710ff1c
# 175  5ab3ec793de622009710ff1c
# 176  5ab3ec793de622009710ff1c
# 177  5ab3ec793de622009710ff1c
# 178  5ab3ec793de622009710ff1c
# 179  5ab3ec793de622009710ff1c
# 180  5ab3ec793de622009710ff1c
# 181  5ab3ec793de622009710ff1c
# 182  5ab3ec793de622009710ff1c
# 183  5ab3ec793de622009710ff1c
# 184  5ab3ec793de622009710ff1c
# 185  5ab3ec793de622009710ff1c
# 186  5ab3ec793de622009710ff1c
# 187  5ab3ec793de622009710ff1c
# 188  5ab3ec793de622009710ff1c
# 189  5ab3ec793de622009710ff1c
#
#                                                content  \
# 0    <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 1    <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 2    <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 3    <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 4    <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 5    <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 6    <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 7    <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 8    <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 9    <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 10   <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 11   <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 12   <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 13   <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 14   <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 15   <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 16   <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 17   <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 18   <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 19   <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 20   <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 21   <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 22   <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 23   <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 24   <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 25   <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 26   <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 27   <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 28   <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 29   <?xml version="1.0" encoding="utf-8"?>\n<inter...
# ..                                                 ...
# 160  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 161  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 162  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 163  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 164  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 165  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 166  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 167  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 168  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 169  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 170  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 171  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 172  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 173  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 174  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 175  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 176  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 177  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 178  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 179  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 180  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 181  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 182  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 183  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 184  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 185  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 186  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 187  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 188  <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 189  <?xml version="1.0" encoding="utf-8"?>\n<inter...
#
#                           _id schema_title
# 0    5b50fb8e86e02c00a68128ba         None
# 1    5b50fb9086e02c00a68128bd         None
# 2    5b50fb9186e02c00a68128c0         None
# 3    5b50fb9286e02c00a68128c3         None
# 4    5b50fb9486e02c00a68128c7         None
# 5    5b50fb9586e02c00a68128ca         None
# 6    5b50fb9686e02c00a68128cd         None
# 7    5b50fb9786e02c00a68128d1         None
# 8    5b50fb9886e02c00a68128d4         None
# 9    5b50fb9986e02c00a68128d7         None
# 10   5b50fb9a86e02c00a68128da         None
# 11   5b50fb9b86e02c00a68128dd         None
# 12   5b50fb9c86e02c00a68128e0         None
# 13   5b50fb9d86e02c00a68128e3         None
# 14   5b50fb9e86e02c00a68128e6         None
# 15   5b50fb9f86e02c00a68128e9         None
# 16   5b50fba086e02c00a68128ec         None
# 17   5b50fba186e02c00a68128ef         None
# 18   5b50fba286e02c00a68128f2         None
# 19   5b50fba386e02c00a68128f5         None
# 20   5b50fba386e02c00a68128f8         None
# 21   5b50fba586e02c00a68128fb         None
# 22   5b50fba686e02c00a68128fe         None
# 23   5b50fba786e02c00a6812901         None
# 24   5b50fba786e02c00a6812904         None
# 25   5b50fba886e02c00a6812907         None
# 26   5b50fba986e02c00a681290a         None
# 27   5b50fbaa86e02c00a681290d         None
# 28   5b50fbac86e02c00a6812910         None
# 29   5b50fbae86e02c00a6812914         None
# ..                        ...          ...
# 160  5b50fc6c86e02c00a6812aa2         None
# 161  5b50fc6d86e02c00a6812aa5         None
# 162  5b50fc6e86e02c00a6812aa8         None
# 163  5b50fc7086e02c00a6812aab         None
# 164  5b50fc7186e02c00a6812aae         None
# 165  5b50fc7386e02c00a6812ab1         None
# 166  5b50fc7486e02c00a6812ab4         None
# 167  5b50fc7686e02c00a6812ab7         None
# 168  5b50fc7786e02c00a6812aba         None
# 169  5b50fc7886e02c00a6812abd         None
# 170  5b50fc7a86e02c00a6812ac0         None
# 171  5b50fc7b86e02c00a6812ac3         None
# 172  5b50fc7c86e02c00a6812ac6         None
# 173  5b50fc7e86e02c00a6812ac9         None
# 174  5b50fc7f86e02c00a6812acc         None
# 175  5b50fc8186e02c00a6812acf         None
# 176  5b50fc8286e02c00a6812ad2         None
# 177  5b50fc8386e02c00a6812ad5         None
# 178  5b50fc8586e02c00a6812ad8         None
# 179  5b50fc8686e02c00a6812adb         None
# 180  5b50fc8786e02c00a6812ade         None
# 181  5b50fc8986e02c00a6812ae1         None
# 182  5b50fc8a86e02c00a6812ae4         None
# 183  5b50fc8b86e02c00a6812ae7         None
# 184  5b50fc8d86e02c00a6812aea         None
# 185  5b50fc8e86e02c00a6812aed         None
# 186  5b50fc8f86e02c00a6812af0         None
# 187  5b5b5acb512605009158dc28         None
# 188  5b5b64a3512605009158dc5d         None
# 189  5b5b6741512605009158dc61         None
#
# [190 rows x 5 columns]

# %% [markdown]
# __MDCS.select_one()__
#
# Get a single record matching the given parameters.  One positional parameter is allowed, which will be tested against title, id, and filename if they are not given separately.  Will issue an error if no or multiple matching records are found.
#
# Parameters
#
# - __title__ (*str, optional*) The title assigned to the record.
#
# - __id__ (*str, optional*) The records's unique id.
#
# - __template__ (*pandas.Series, str or dict, optional*) The template associated with the record.  If str, will be searched against the template's id, title, and filename.  If dict, allows multiple template parameters to be specified in matching correct template.
#
# - __format__ (*str, optional*) Format to return record content as, can be either 'xml', or 'json'.
#
# Returns
#
# - (*pandas.Series*) The matching record.

# %%
record = curator.select_one(template='Potential', title='potential.2017--Purja-Pun-G-P--Au')
record
# Out:
# title                           potential.2017--Purja-Pun-G-P--Au
# schema                                   5ab3ec793de622009710ff1c
# content         <?xml version="1.0" encoding="utf-8"?>\n<inter...
# _id                                      5b50fc8286e02c00a6812ad2
# schema_title                                                 None
# Name: 0, dtype: object

# %% [markdown]
# If format is not given or 'xml', the record's content will be an xml formatted string.

# %%
record.content
# Out:
# '<?xml version="1.0" encoding="utf-8"?>\n<interatomic-potential><key>ef908258-25d1-439e-8223-3bf4df924ed0</key><id>2017--Purja-Pun-G-P--Au</id><record-version>2018-06-12</record-version><description><citation><document-type>unspecified</document-type><title>to be published</title><author><given-name>G.P.</given-name><surname>Purja Pun</surname></author><publication-date><year>2017</year></publication-date><bibtex>@unpublished{2017--Purja-Pun-G-P--Au,\\n author = {G.P. Purja Pun},\\n note = {2017--Purja-Pun-G-P--Au},\\n title = {to be published},\\n year = {2017}\\n}\\n\\n</bibtex></citation></description><implementation><key>8bfd0a48-8558-46f9-9d20-cd9e92cb83ae</key><id>2017--Purja-Pun-G-P--Au--LAMMPS--ipr1</id><status>active</status><date>2017-09-07</date><type>LAMMPS pair_style eam/alloy</type><notes><text>These files were sent by G.P. Purja Pun (George Mason) on 7 Sept. 2017 and posted with his permission.</text></notes><artifact><web-link><URL>www.ctcms.nist.gov/potentials/Download/2017--Purja-Pun-G-P-Mishin-Y--Au/Au_GLJ10_3.eam.alloy</URL><link-text>Au_GLJ10_3.eam.alloy</link-text></web-link></artifact></implementation><element>Au</element></interatomic-potential>'

# %% [markdown]
# If format is 'json', the content will automatically be converted to a Python OrderedDict.

# %%
record = curator.select_one(template='Potential', title='potential.2017--Purja-Pun-G-P--Au', format='json')
record.content
# Out:
# OrderedDict([('interatomic-potential',
#               OrderedDict([('key', 'ef908258-25d1-439e-8223-3bf4df924ed0'),
#                            ('id', '2017--Purja-Pun-G-P--Au'),
#                            ('record-version', '2018-06-12'),
#                            ('description',
#                             OrderedDict([('citation',
#                                           OrderedDict([('document-type',
#                                                         'unspecified'),
#                                                        ('title',
#                                                         'to be published'),
#                                                        ('author',
#                                                         OrderedDict([('given-name',
#                                                                       'G.P.'),
#                                                                      ('surname',
#                                                                       'Purja Pun')])),
#                                                        ('publication-date',
#                                                         OrderedDict([('year',
#                                                                       2017)])),
#                                                        ('bibtex',
#                                                         '@unpublished{2017--Purja-Pun-G-P--Au,\\n author = {G.P. Purja Pun},\\n note = {2017--Purja-Pun-G-P--Au},\\n title = {to be published},\\n year = {2017}\\n}\\n\\n')]))])),
#                            ('implementation',
#                             OrderedDict([('key',
#                                           '8bfd0a48-8558-46f9-9d20-cd9e92cb83ae'),
#                                          ('id',
#                                           '2017--Purja-Pun-G-P--Au--LAMMPS--ipr1'),
#                                          ('status', 'active'),
#                                          ('date', '2017-09-07'),
#                                          ('type',
#                                           'LAMMPS pair_style eam/alloy'),
#                                          ('notes',
#                                           OrderedDict([('text',
#                                                         'These files were sent by G.P. Purja Pun (George Mason) on 7 Sept. 2017 and posted with his permission.')])),
#                                          ('artifact',
#                                           OrderedDict([('web-link',
#                                                         OrderedDict([('URL',
#                                                                       'www.ctcms.nist.gov/potentials/Download/2017--Purja-Pun-G-P-Mishin-Y--Au/Au_GLJ10_3.eam.alloy'),
#                                                                      ('link-text',
#                                                                       'Au_GLJ10_3.eam.alloy')]))]))])),
#                            ('element', 'Au')]))])

# %% [markdown]
# __MDCS.query()__
#
# Select records based on MongoDB-style query string.
#
# Parameters
#
# - __query__ (*str*) A MongoDB-style query string.
#
# - __format__ (*str, optional*) Format to return record content as, can be either 'xml', or 'json'.
#
# Returns
#
# - (*pandas.DataFrame*) All matching records.
#
# __NOTE__: Query path starts at the level shown in the returned DataFrames: it has roots "title", "schema", "content", "\_id", and "schema_title".  Querying based on the record's content then follow "content.path".

# %%
# query to potentials containing gold interactions
query = '{"content.interatomic-potential.element":"Au"}'

curator.query(query=query)
# Out:
#                                                 title  \
# 0   potential.1987--Ackland-G-J-Tichy-G-Vitek-V-Fi...
# 1   potential.1989--Adams-J-B-Foiles-S-M-Wolfer-W-...
# 2   potential.2004--Zhou-X-W-Johnson-R-A-Wadley-H-...
# 3   potential.2004--Zhou-X-W-Johnson-R-A-Wadley-H-...
# 4   potential.2005--Grochola-G-Russo-S-P-Snook-I-K...
# 5   potential.2009--Zhakhovskii-V-V-Inogamov-N-A-P...
# 6                    potential.2010--Olsson-P-A-T--Au
# 7   potential.2017--OBrien-C-J-Barr-C-M-Price-P-M-...
# 8                   potential.2017--Purja-Pun-G-P--Au
# 9   potential.2018--Starikov-S-V-Lopanitsyna-N-Y-S...
# 10  potential.2012--Norman-G-E-Starikov-S-V-Stegai...
#
#                       schema  \
# 0   5ab3ec793de622009710ff1c
# 1   5ab3ec793de622009710ff1c
# 2   5ab3ec793de622009710ff1c
# 3   5ab3ec793de622009710ff1c
# 4   5ab3ec793de622009710ff1c
# 5   5ab3ec793de622009710ff1c
# 6   5ab3ec793de622009710ff1c
# 7   5ab3ec793de622009710ff1c
# 8   5ab3ec793de622009710ff1c
# 9   5ab3ec793de622009710ff1c
# 10  5ab3ec793de622009710ff1c
#
#                                               content  \
# 0   <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 1   <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 2   <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 3   <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 4   <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 5   <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 6   <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 7   <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 8   <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 9   <?xml version="1.0" encoding="utf-8"?>\n<inter...
# 10  <?xml version="1.0" encoding="utf-8"?>\n<inter...
#
#                          _id schema_title
# 0   5b50fb9786e02c00a68128d1    Potential
# 1   5b50fb9b86e02c00a68128dd    Potential
# 2   5b50fbd186e02c00a6812956    Potential
# 3   5b50fbd486e02c00a681295c    Potential
# 4   5b50fbe886e02c00a6812989    Potential
# 5   5b50fc1386e02c00a68129e2    Potential
# 6   5b50fc1a86e02c00a68129f1    Potential
# 7   5b50fc8186e02c00a6812acf    Potential
# 8   5b50fc8286e02c00a6812ad2    Potential
# 9   5b50fc8e86e02c00a6812aed    Potential
# 10  5b5b5acb512605009158dc28    Potential

# %% [markdown]
# __MDCS.type_select_all()__
#
# __MDCS.type_select()__
#
# __MDCS.type_select_one()__
#
# To be added later...

# %% [markdown]
# ## 3. Adding content

# %% [markdown]
# __MDCS.curate()__
#
# Curates (uploads) a record to the MDCS instance.
#
# Parameters
#
# - __content__ (*str*) The xml content or path to a file containing the content of the record to curate.
#
# - __title__ (*str*) The name to assign to the record as it will be stored in the database.
#
# - __template__ (*pandas.Series, str or dict, optional*) The template associated with the record.  If str, will be searched against the template's id, title, and filename.  If dict, allows multiple template parameters to be specified in matching correct template.

# %%
# Get an existing record
record = curator.select_one(template='Potential', title='potential.2017--Purja-Pun-G-P--Au')

# Copy contents to test uploading
title = "test"
template = 'Potential'
content = record.content

# Curate record
curator.curate(content, title, template)

# %%
# Show that record is in database
curator.select(title=title, template=template)
# Out:
#   title                    schema  \
# 0  test  5ab3ec793de622009710ff1c
#
#                                              content  \
# 0  <?xml version="1.0" encoding="utf-8"?>\n<inter...
#
#                         _id schema_title
# 0  5b5e0e35512605009158dd03         None

# %% [markdown]
# __MDCS.delete()__
#
# Deletes a record from the MDCS instance.  The parameters must uniquely identify a single record in the database.
#
# Parameters
#
# - __record__ (*pandas.Series, optional*) The record to delete.  Cannot be given with the other parameters.
#
# - __title__ (*str, optional*) The title assigned to the record.
#
# - __id__ (*str, optional*) The record's unique id.
#
# - __template__ (*pandas.Series, str or dict, optional*) The template associated with the record.  If str, will be searched against the template's id, title, and filename.  If dict, allows multiple template parameters to be specified in matching correct template.
#
# Returns
#
# - (*str*) The web response.

# %%
# Delete the test record
curator.delete(title=title, template=template)

# Show that record is gone
curator.select(title=title, template=template)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# __MDCS.template_add()__
#
# __MDCS.type_add()__
#
# To be added later...

# %% [markdown]
# ## 4. Blobs

# %% [markdown]
# __MDCS.blob_upload()__
#
# Uploads a blob to the MDCS instance.
#
# Parameters
#
# - __filename__ (*str*) Path to file to upload
#
# Returns
#
# - (*str*) The URL where the blob can be downloaded.

# %%
# Create test file
fname = 'test.txt'
with open(fname, 'w') as f:
    f.write('This is a test')

# Upload the file
url = curator.blob_upload(fname)
print(url)

# Delete local copy of the file
os.remove(fname)
# Out:
# https://potentials.nist.gov/rest/blob?id=5b5e0e48512605009158dd09

# %% [markdown]
# __MDCS.blob_download()__
#
# Download a blob from the MDCS instance.
#
# Parameters
#
# - __url__ (*str*) The URL where the blob can be downloaded.
#
# - __filename__ (*str, optional*) Path to file where the content can be saved.  If value is None (default) then the blob is returned as bytes content.
#
# Returns
#
# - (*bytes*) The downloaded content (only returned if filename is None).

# %%
blob = curator.blob_download(url)
print(blob)
# Out:
# b'This is a test'
